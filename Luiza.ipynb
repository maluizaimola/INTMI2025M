# %% [markdown]
# <a href="https://colab.research.google.com/github/maluizaimola/INTMI2025M/blob/main/Luiza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #algoritmo e lógica de programação

# %% [markdown]
# #variáveis

# %%
a=10
b=15
print(a+b)
# Out:
# 25

# %% [markdown]
# ##Tipos de dados
#
# int-inteiro-para números inteiros
#
#
# float-flutuante-para números com vírgula
#
# str-string- para palavras e textos
#
# bool-booleano- para verdadeiro e falso (binário)- true ou false

# %%
x=int(input("Digite um número:"))
y=float(input("Digite o número com vírgula:"))
z= str(input("Digite um texto:"))
w= bool(input("Digite um valor binário:"))
# Out:
# Digite um número:15
# Digite o número com vírgula:1.5
# Digite um texto:macarrão
# Digite um valor binário:false

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 15
# 1.5
# macarrão
# True

# %%
print( "Este é um número:", x , " e o próximo é um flutuante:" , y)
# Out:
# Este é um número: 15  e o próximo é um flutuante: 1.5

# %% [markdown]
# ##Operadores
#
# + Adição
#
# - Subtração
#
# * Multiplicação
#
# Divisão /
#
# Potência ^
#
# Resto da divisão %

# %% [markdown]
# 1- Crie um algoritmo que receba 2 números, em variáveis diferentes ( num1 - num2), depois faça as quatro operações com esses dois números e mostre o resultado na tela.

# %%
num1= int(input( " Digite um número:"))

num2=int(input( " Digite um número:"))

print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
#  Digite um número:4
#  Digite um número:5
# 9
# -1
# 20
# 0.8

# %%
print(f"O primeiro número é {num1} e o segundo é {num2}")
# Out:
# O primeiro número é 4 e o segundo é 5

# %% [markdown]
# 2- Crie um algoritmo que receba o nome do usuário na variável (nome) e a idade na variável (idade), e depois mostre n atela a seguinte frase:
#
# Olá, meu nome é (nome) e eu tenho (idade) anos!

# %%
#entrada
nome =str(input("digite um texto:"))
idade =int(input(" digite um número:"))
#saídas
print(f"Olá, meu nome é {nome} e tenho {idade} anos!")
# Out:
# digite um texto:Luiza
#  digite um número:16
# Olá, meu nome é Luiza e tenho 16 anos!

# %%
#entradas
peso=float(input("digite o seu peso(kg):"))
altura=float(input("digite a sua altura"))

#processamento
imc=peso/(altura**2)

#saídas
print(f" O seu imc é:{imc:.2f}")
# Out:
# digite o seu peso(kg):61
# digite a sua altura1.65
#  O seu imc é:22.41

# %% [markdown]
# 3-Crie um algoritmo que receba o nome do aluno, e 3 notas. Depois calcule a média das notas e imprima na tela:
#
# O aluno: (aluno) está com (média) de média!

# %% [markdown]
# Peça um número e informe se ele é maior que 10. Crie um algoritmo em Python para fazer essa verificação.
# Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.
# Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.
# Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.
# Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.
# Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.
# Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.
# Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.
# Peça um ano e informe se ele é bissexto. Crie um algoritmo em Python que verifique se o ano é divisível por 4 e não por 100, exceto se também for divisível por 400.
# Peça a quantidade de horas trabalhadas e o valor por hora. Se trabalhou até 40 horas, calcule o salário normalmente (horas × valor por hora). Se trabalhou mais de 40 horas, as horas extras devem ter um adicional de 50% (horas extras × valor por hora × 1.5). Crie um algoritmo em Python que realize esse cálculo corretamente.

# %%
numero = float(input("Digite um número: "))

if numero > 10:
    print("O número é maior que 10.")
else:
    print("O número não é maior que 10.")
# Out:
# Digite um número: 5
# O número não é maior que 10.

# %%
numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
    print("O número é par.")
else:
    print("O número é ímpar.")
# Out:
# Digite um número inteiro: 6
# O número é par.

# %%
nome = input("Digite um nome: ")

if 'a' in nome.lower():
    print("O nome contém a letra 'a'.")
else:
    print("O nome não contém a letra 'a'.")
# Out:
# Digite um nome: luiza
# O nome contém a letra 'a'.

# %%
numero = int(input("Digite um número: "))

if numero % 5 == 0:
    print("O número é múltiplo de 5.")
else:
    print("O número não é múltiplo de 5.")
# Out:
# Digite um número: 13
# O número não é múltiplo de 5.

# %%
temperatura = float(input("Digite a temperatura atual (°C): "))

if temperatura > 30:
    print("Está quente.")
else:
    print("Está frio.")
# Out:
# Digite a temperatura atual (°C): 24
# Está frio.

# %%
opcao = input('Digite "S" para continuar ou "N" para sair: ').upper()

if opcao == "S":
    print("Você escolheu continuar.")
elif opcao == "N":
    print("Você escolheu sair.")
else:
    print("Opção inválida.")
# Out:
# Digite "S" para continuar ou "N" para sair: n
# Você escolheu sair.

# %%
numero = float(input("Digite um número: "))

if numero > 0:
    print("O número é positivo.")
elif numero < 0:
    print("O número é negativo.")
else:
    print("O número é zero.")
# Out:
# Digite um número: -79
# O número é negativo.

# %%
dia = int(input("Digite um número de 1 a 7: "))

if dia == 1:
    print("Domingo")
elif dia == 2:
    print("Segunda-feira")
elif dia == 3:
    print("Terça-feira")
elif dia == 4:
    print("Quarta-feira")
elif dia == 5:
    print("Quinta-feira")
elif dia == 6:
    print("Sexta-feira")
elif dia == 7:
    print("Sábado")
else:
    print("Número inválido! Digite um número entre 1 e 7.")
# Out:
# Digite um número de 1 a 7: 6
# Sexta-feira

# %%
ano = int(input("Digite um ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print("O ano é bissexto.")
else:
    print("O ano não é bissexto.")
# Out:
# Digite um ano: 2017
# O ano não é bissexto.

# %%
horas_trabalhadas = float(input("Digite a quantidade de horas trabalhadas: "))
valor_hora = float(input("Digite o valor por hora: "))

if horas_trabalhadas <= 40:
    salario = horas_trabalhadas * valor_hora
else:
    horas_extras = horas_trabalhadas - 40
    salario = (40 * valor_hora) + (horas_extras * valor_hora * 1.5)

print(f"Salário total: R$ {salario:.2f}")
# Out:
# Digite a quantidade de horas trabalhadas: 12
# Digite o valor por hora: 400
# Salário total: R$ 4800.00
